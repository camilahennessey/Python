# %% [markdown]
# <h1 style='text-align:center;margin:0'>A1: Analytics Report</h1>
# <h1 style='text-align:center;margin:0'>Camila Hennessey</h1>

# %% [markdown]
# <h1 style='text-align:center;margin:0'>Oil and Gas Trading Optimization</h1>

# %% [markdown]
# <h1 style='text-align:center;margin:0'>Problem Statement</h1>
#
# Our task was to help the Company improve its trading decision process based on available data. Currently, the experts in charge of forecasting the production predictions are doing it manually, which can be time-consuming, prone to human error, and less efficient than it could be. Therefore, the Company is looking for a way to improve this process to make the predictions more efficient and accurate,  helping to make better decisions about trading production rights for oil and gas wells by relying on more precise and faster forecasts of future production. Nonetheless, before suggesting any change related to the forecast itself, we considered that the business situations impacting the oil and gas trading the Company needs to understand better are:
#
# - Environmental Concerns with Hydraulic Fracturing
# - Economic Dependence on Oil and Gas
# - Global Energy Landscape Shifts
# - Water Use in Hydraulic Fracturing
#
# By leveraging data analytics, the Company can navigate the complex legal that the production rights of trading involve with greater confidence, transparency, and profitability. Failing to make well-informed decisions can lead to significant financial losses, legal risks, and reputational damage. By embracing automation and leveraging the power of data, the Company can minimize legal risks, optimize contracts, ensure compliance, and improve its financial performance.

# %% [markdown]
# ## Problem No. 1: Environmental Concerns with Hydraulic Fracturing
#
# According to the New Mexico Bureau of Geology & Mineral Resources, hydraulic fracturing or fracking, has revolutionized the oil and gas industry by enabling access to previously unreachable resources. Thus, it raises significant environmental concerns, including potential groundwater contamination and seismic activities(2014). Addressing environmental concerns is essential for maintaining the industry's social license to operate, ensuring compliance with increasingly stringent regulations, and protecting local communities and ecosystems. Therefore, the approach to the problem should be multi-disciplinary, involving collaboration with environmental scientists, regulatory bodies, and the Company. Potential stakeholder disagreements might conflicts between industry proponents advocating for economic benefits and environmentalists concerned about long-term impacts. Analytics can help bridge this gap by providing data-driven insights into the environmental impacts and identifying safer practices. Business-wise, the question will be: How can we minimize the environmental impact of hydraulic fracturing, particularly concerning water contamination and seismic activity?

# %% [markdown]
# ## Problem No. 2: Economic Dependence on Oil and Gas
#
# Based on the information provided, it is essential to highlight how the state of New Mexico economically depends on a sustainable rate of oil and gas natural production (New Mexico Bureau of Geology & Mineral Resources, 2014). Market volatility and long-term shifts towards renewable energy affect them considerably. Economic diversification is critical for reducing dependency on a single commodity, ensuring long-term economical stability, and creating resilient communities. Then identifying and investing in alternative industries, such as renewable energy, technology, and services, while supporting workforce retraining and development is necessary. Balancing the immediate economic benefits of oil and gas exploitation with the need for diversification and sustainability can lead to disagreements among policymakers, industry players, and the public. The business question is how regions heavily reliant on oil and gas revenues can diversify their economies to mitigate risks associated with market volatility.

# %% [markdown]
# ## Problem No. 3: Global Energy Landscape Shifts
#
# The global shift towards renewable energy and away from fossil fuels is reshaping the energy landscape, presenting challenges and opportunities for traditional oil and gas companies. The United States has become the world's largest natural gas producer. In addition, it is on track to become the largest oil producer due to its dominance in the dynamics of international energy markets (New Mexico Bureau of Geology & Mineral Resources, 2014). Understanding and adapting to these shifts are vital for navigating the future energy market, capitalizing on new opportunities, and contributing to the global sustainability agenda. This could be approached by embracing innovation in energy production, investing in renewables, and forming strategic alliances to expand into new markets. There may be resistance from within the oil and gas industry due to perceived threats to traditional revenue streams. However, a long-term vision towards energy transition is necessary for sustainability. Transitioning to renewable energy sources involves navigating complex international environmental agreements and adapting to a rapidly evolving global regulatory landscape. Companies must stay informed about these changes to avoid legal pitfalls and capitalize on new opportunities. Business-wise, in the context of global shifts towards renewable energy, how can oil and gas companies adapt their strategies to remain competitive and sustainable?

# %% [markdown]
# ## Problem No. 4: Water Use in Hydraulic Fracturing
#
# Fracking requires large volumes of water, leading to concerns over water scarcity and management, especially in drought-prone areas. Efficient water use addresses critical environmental and community concerns, helps comply with regulatory requirements, and ensures the sustainability of hydraulic fracturing operations. Developing and implementing water-saving technologies, enhancing water recycling efforts, and utilizing alternative water sources. Water rights and usage are highly regulated areas, with specific laws governing the extraction and disposal of water. The Company must navigate these legal requirements carefully to ensure compliance and avoid disputes with local communities and environmental groups. The competition for water resources between the oil and gas industry and local communities requires careful management to ensure equitable access and sustainability. The business question proposed is: what strategies can be employed to significantly reduce freshwater use in hydraulic fracturing operations, ensuring sustainability and addressing local water scarcity concerns?

# %% [markdown]
# <h1 style='text-align:center;margin:0'>Results</h1>

# %% [markdown]
# ## Problem No. 1: Addressing Environmental Concerns with Hydraulic Fracturing
#
# Our comprehensive analysis of water usage within hydraulic fracturing operations has unearthed critical insights pivotal to addressing the industry's environmental footprint, particularly concerning water resource management. Through diligent examination of total water pumped, the calculation of water to oil ratios, and detailed evaluations of operator-specific water usage, we have pinpointed areas ripe for enhancement and benchmarking, laying the groundwork for significant environmental stewardship and operational efficiency improvements. The cornerstone of our analysis, the overall water to oil ratio, serves as an industry-wide efficiency benchmark. A lower ratio is indicative of more prudent water use in proportion to oil production, a key factor in diminishing the environmental repercussions of our operations. Disparities in water use efficiency among operators have unveiled a spectrum of performance, presenting a clear pathway for less efficient entities to integrate best practices and cutting-edge technologies aimed at curbing water consumption. Our longitudinal analysis of the gas to water production ratio furnishes a panoramic view of the industry's stride towards or away from efficiency over time. A consistent uptick in this ratio would signify effective measures to moderate water use vis-à-vis gas production, underscoring the industry's commitment to sustainable water management practices.
#
# ***Strategic Recommendations***
#
# Instituting robust monitoring mechanisms to promptly identify and ameliorate potential contaminants can significantly curtail the risk of extensive environmental detriment and the ensuing financial burdens. Allocating resources towards the development and adoption of safer fracking methodologies not only mitigates the risk of operational mishaps but also shields against the financial and legal ramifications of environmental incidents.
#
# ***Legal Implications and Risk Management***
#
# Adhering to the stringent environmental regulations is non-negotiable. Non-compliance could precipitate severe penalties, legal challenges, and the potential forfeiture of operational licenses, thereby endangering our license to operate within the communities we serve. The specter of litigation for purported environmental violations looms large, with potential outcomes including substantial financial liabilities and reputational damage. It is imperative that our operations not only meet but exceed regulatory expectations to safeguard against such risks.
#
# ***Conclusion***
#
# The essence of our findings underscores the importance of deploying data-driven strategies to refine water use within hydraulic fracturing operations. Embracing sustainable practices not only aligns with our environmental responsibilities but also enhances our operational efficacy. The path forward demands a concerted effort to expand upon our current analysis, incorporating a wider array of environmental impact data and conducting in-depth longitudinal studies to foster continuous improvement and robust engagement with all stakeholders on the journey towards sustainable hydraulic fracturing operations.

# %% [markdown]
# ## Problem No. 2: Economic Dependence on Oil and Gas
#
# Our analytical dive into the cumulative production by region has surfaced critical insights into the economic dependencies that certain states and provinces harbor towards the oil and gas sector. These dependencies render such regions inherently more susceptible to the whims of market volatility and the inexorable shift towards renewable energy sources. A detailed examination of production efficiency across wells has unveiled significant variances in performance, presenting a tangible opportunity to enhance production optimization and mitigate the economic vulnerabilities tied to underperforming assets. The compelling need for regions steeped in oil and gas reliance to embark on a path towards economic diversification cannot be overstated. Our analysis, through the prism of production efficiency and cumulative production data, acts as a beacon, guiding stakeholders towards recognizing both the latent vulnerabilities and the untapped opportunities for growth beyond the confines of the traditional energy paradigm. A forward-looking strategy must also encompass workforce dynamics, identifying burgeoning sectors ripe for diversification, and embedding the socio-political nuances that underpin economic resilience. Such a multifaceted approach promises not only to cushion against the shocks of market fluctuations but also to pave the way for sustainable economic prosperity in the era of renewable energy ascendancy.
#
# **Risk Management Framework**
#
# Diluting the economic concentration in oil and gas through strategic diversification can shield regions from the vicissitudes of energy market volatility, ensuring a more robust economic fabric. In addition, proactive investments in workforce re-skilling and up-skilling initiatives are paramount. They are the bedrock upon which the successful pivot to emergent industries, including renewables, can be achieved, minimizing the specter of unemployment in the wake of economic transitions.
#
# **Legal Considerations and Strategic Compliance**
#
# The diversification journey may entail intricate trade and investment legal landscapes, especially pertinent when courting foreign investments or venturing into new markets. Strategic legal foresight is imperative in this regard. Foraying into new sectors, notably renewable energy, mandates a thorough navigation of varied regulatory frameworks. Ensuring compliance is pivotal to forestall potential legal hurdles and facilitate a seamless sectoral transition.
#
# **Conclusion**
#
# Our analysis, crystallized through the lens of regional economic dependencies and production efficiency variances, serves as a clarion call for a strategic recalibration towards economic diversification and resilience building. It is incumbent upon us to harness these insights, forging ahead with a data-informed strategy that meticulously addresses the multifaceted challenges and opportunities inherent in the global shift towards renewable energy. Your stewardship and vision are critical as we endeavor to chart a course towards sustainable economic growth and resilience in the face of evolving energy paradigms.

# %% [markdown]
# ## Problem No. 3: Global Energy Landscape Shifts
#
# Our comprehensive analysis of yearly cumulative production within the oil and gas industry has illuminated pivotal trends that merit our attention. A discernible inclination towards increased gas production has emerged, resonating with the broader global narrative of transitioning towards cleaner energy sources. Through strategic visualizations, we have observed that while oil continues to play a dominant role in our portfolio, the ascent of gas underscores a pivotal alignment with international energy sustainability goals. Our exploration into the distribution of production methods has unveiled a spectrum of operational strategies, underscoring our industry's commitment to pursuing efficiency and sustainability. The insights into peak production trends further refine our understanding of the interplay between technological advancements and market dynamics, shaping our strategic decision-making and operational efficiencies. The current landscape necessitates a proactive stance towards embracing innovation, deepening our investment in renewable energy sources, and fostering agility to thrive in a market characterized by rapid evolutions and regulatory shifts. By anchoring our strategies on the data-driven insights gleaned from our analysis, we position ourselves to not only navigate but also lead in the era of global energy transitions. Collaborating with entities across the renewable energy spectrum can mitigate transition risks, enabling us to share knowledge, leverage new technologies, and co-create sustainable energy solutions. A dynamic approach to capital allocation will be crucial. By staying adaptable, we can seize emerging opportunities in the renewable sector while managing the potential obsolescence of traditional assets.
#
# **Navigating Legal and Regulatory Terrain**
#
# Our operations and strategic investments must be meticulously aligned with the stipulations of global climate accords, necessitating a keen understanding of their legal ramifications on our business practices. The shift towards a low-carbon economy is accompanied by a changing regulatory framework. Proactive legal risk management and compliance strategies will be instrumental in navigating this landscape, ensuring our operational viability and strategic growth.
#
# **Conclusion**
#
# The nuanced trends revealed through our yearly cumulative production analysis serve as a clarion call for strategic adaptation and innovation. By leveraging these insights, we can spearhead a strategic pivot that not only aligns with global energy transition mandates but also secures our competitive edge and sustainability in the forthcoming energy paradigm. Your leadership and visionary direction will be pivotal as we embark on this transformative journey, reshaping our legacy in the energy sector for a sustainable future.

# %% [markdown]
# ## Problem No. 4: Water Use in Hydraulic Fracturing
#
# Our in-depth analysis of water use within hydraulic fracturing operations has yielded critical insights, showcasing a spectrum of water use efficiency across different operators. This variance underscores the potential for industry-wide improvement, particularly in adopting practices that significantly curtail freshwater usage. The analysis reveals diverse efficiency levels in the Water to Oil Ratio by different operators. Identifying leaders in water use efficiency highlights actionable best practices that can serve as benchmarks for the entire industry, suggesting a pathway towards minimizing freshwater consumption. Our examination of water use trends over time suggests an encouraging trajectory towards greater efficiency. This trend reflects a collective industry movement towards sustainability, driven by both external pressures and internal commitments to responsible resource management. The comprehensive data on total water produced and injected underscores ongoing efforts towards water recycling and the exploration of alternative fluid sources. These practices are pivotal, yet there remains substantial scope to enhance these efforts, further reducing reliance on freshwater sources. Our findings from the yearly gas to water production ratio trends indicate an increasing efficiency in gas extraction processes, aligning with the broader transition towards cleaner energy sources. This efficiency gain not only reflects technological advancements but also a strategic alignment with global sustainability goals.
#
# **Ensuring Sustainability Through Risk Management**
#
# By prioritizing water recycling and reuse, we can dramatically diminish our freshwater footprint, directly addressing risks associated with water scarcity and stringent regulatory frameworks governing water use. Proactively identifying and leveraging alternative water sources for our operations will play a crucial role in mitigating the risks tied to freshwater dependency, ensuring operational resilience and sustainability.
#
# **Navigating the Legal Terrain**
#
#
# Vigilant management of water rights and adherence to prevailing water use regulations are non-negotiable to forestall legal disputes and operational hindrances. The competition for scarce water resources necessitates a strategic approach to community engagement and dispute resolution, aiming to avert legal challenges and foster community goodwill.
#
# **Conclusion**
#
# The synthesized insights from our water use analysis highlight the imperative for continuous improvement and innovation in water management practices within hydraulic fracturing operations. Embracing water-saving technologies, bolstering recycling efforts, and exploring alternative sources are indispensable strategies for enhancing sustainability and regulatory compliance. As we navigate the complexities of environmental stewardship, economic imperatives, and the global energy transition, our collective commitment to sustainable practices and strategic risk management will be paramount in positioning our operations for long-term success and resilience.

# %% [markdown]
# <h1 style='text-align:center;margin:0'>Assumptions Made</h1>

# %% [markdown]
# ## Problem 1: Addressing Environmental Concerns with Hydraulic Fracturing
#
# The analysis assumes that the fracking fluids used across different operations have a similar composition, facilitating a generalized assessment of potential environmental impacts. It also assumes that the volume of water used in fracking operations is considered directly correlated to the environmental impact, streamlining the analysis process.

# %% [markdown]
# ## Problem No. 2: Economic Dependence on Oil and Gas
#
# The analysis is based on the assumption that the demand for oil and gas remains stable in the short to medium term, focusing on the current economic dependencies. Significant opportunities for economic diversification within the analyzed regions are presumed available, enriching the discussion on reducing economic dependencies.

# %% [markdown]
# ## Problem No. 3: Global Energy Landscape Shifts
#
# It is assumed that traditional oil and gas companies can adapt their strategies to remain competitive amidst the global shift towards renewable energy. The analysis proceeds under the assumption of a stable regulatory environment concerning renewable energy and fossil fuels.

# %% [markdown]
# ## Problem No. 4: Water Use in Hydraulic Fracturing
#
# Existing water recycling technologies are presumed effective and implementable at scale across different fracking operations.Alternative water sources are assumed to be readily available and suitable for use in hydraulic fracturing operations across various regions.

# %% [markdown]
# <h1 style='text-align:center;margin:0'>Limitations</h1>

# %% [markdown]
# ## Problem 1: Addressing Environmental Concerns with Hydraulic Fracturing
#
# The assumption of uniform fracking fluid composition overlooks the variability and proprietary nature of these mixtures, potentially underestimating specific environmental impacts. The direct correlation between water use and environmental impact does not account for the complex interactions and cumulative effects of fracking operations on local ecosystems.

# %% [markdown]
# ## Problem No. 2: Economic Dependence on Oil and Gas
#
# The stability of market demand does not consider potential long-term shifts in global energy consumption patterns, possibly affecting the relevance of findings over time. Assuming broad diversification opportunities without region-specific economic analyses might not accurately capture the feasibility and impact of such strategies in different contexts.

# %% [markdown]
# ## Problem No. 3: Global Energy Landscape Sh
#
# The assumption about the adaptability of oil and gas companies may not fully account for structural, technological, and financial barriers to embracing renewable energy. Assuming a stable regulatory environment may not reflect the dynamic and often unpredictable nature of energy policy, affecting the reliability of strategic recommendations.

# %% [markdown]
# ## Problem No. 4: Water Use in Hydraulic Fracturing
#
# The effectiveness and scalability of water recycling technologies may vary, and assumptions about their widespread applicability may not hold in all operational contexts. The availability and suitability of alternative water sources for fracking operations can differ significantly by region, affecting the generalizability of water use reduction strategies.

# %% [markdown]
# <h1 style='text-align:center;margin:0'>Data</h1>

# %% [markdown]
# The strategic decision to utilize the Metadata and Production Data datasets was driven by our objective to conduct a multifaceted analysis of hydraulic fracturing operations, focusing on water use efficiency, cumulative production trends, and the broader implications of global energy transitions. The Metadata dataset provided invaluable insights into well characteristics, geographical locations, and operational parameters, setting the foundation for understanding the environmental and operational dimensions of our analysis. Conversely, the Production Data dataset offered detailed production metrics, including volumes of oil, gas, and water produced, which are crucial for evaluating production efficiency, water use practices, and the economic impact of our operations on regional economies.
#
# **Data Quality and Integrity**
#
# Upon thorough review, both datasets demonstrated a high degree of integrity and reliability, characterized by comprehensive coverage and granularity of data points. However, challenges were encountered, including instances of missing values and varying data formats, necessitating meticulous data cleaning and standardization processes to ensure analytical accuracy. Despite these hurdles, the richness and depth of the datasets underpinned a robust analytical framework, enabling precise and insightful conclusions.
#
# **Constraints and Limitations**
#
# While both datasets proved to be instrumental in our analysis, several constraints were identified that could potentially impact the depth and scope of our findings:
#
# - The datasets' time span may not fully capture long-term trends or the latest shifts in industry practices, particularly in the rapidly evolving landscape of renewable energy and technological advancements.
#
# - The datasets predominantly reflect operations within certain regions, which may limit the applicability of our findings across the global oil and gas industry landscape.
#
# - While providing a broad overview of production and water use, the datasets may lack the granularity needed to drill down into specific operational techniques or the efficacy of individual water management practices.
#
# - The datasets focus primarily on operational metrics and do not directly incorporate regulatory changes, environmental impact assessments, or community engagement measures, which are critical components of holistic sustainability analysis.

# %%
# Libraries imported for data manipulation and analysis

import pandas as pd
from pathlib import Path
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")

# %%
# Creation of a variable representing the directory named 'data' to easily reference files and directories within the 'data' directory using methods and attributes provided by the Path object.

datapath = Path('data')

# %% [markdown]
# ## Dataset 1: Metadata

# %%
# Loading data
metadata_path = '/data/Metadata.xlsx'
metadata = pd.read_excel(datapath / 'Metadata.xlsx')

# %%
# Display of first 5 rows
metadata.head()
# Out:
#         API_UWI  Unformatted_API_UWI       API_UWI_12  Unformatted_API_UWI_12  \
# 0  30-015-43706           3001543706  30-015-43706-00            300154370600
# 1  30-025-44687           3002544687  30-025-44687-00            300254468700
# 2  30-025-46812           3002546812  30-025-46812-00            300254681200
# 3  30-025-44013           3002544013  30-025-44013-00            300254401300
# 4  30-015-49326           3001549326  30-015-49326-00            300154932600
#
#            API_UWI_14  Unformatted_API_UWI_14           WellID  \
# 0  30-015-43706-00-00          30015437060000  840300003495031
# 1  30-025-44687-00-00          30025446870000  840300004752843
# 2  30-025-46812-00-00          30025468120000  840300005432761
# 3  30-025-44013-00-00          30025440130000  840300004671472
# 4  30-015-49326-00-00          30015493260000  840300019360808
#
#       CompletionID     WellPadID WellPadDirection  ...  \
# 0  840301002145615  30-015-43706                N  ...
# ...

# %%
# Summary statistics of the numerical columns in metadata dataframe
metadata.describe()
# Out:
#        Unformatted_API_UWI  Unformatted_API_UWI_12  Unformatted_API_UWI_14  \
# count         2.863000e+03            2.863000e+03            2.863000e+03
# mean          3.002076e+09            3.002076e+11            3.002076e+13
# min           3.001539e+09            3.001539e+11            3.001539e+13
# 25%           3.001546e+09            3.001546e+11            3.001546e+13
# 50%           3.002543e+09            3.002543e+11            3.002543e+13
# 75%           3.002546e+09            3.002546e+11            3.002546e+13
# max           3.002551e+09            3.002551e+11            3.002551e+13
# std           4.991529e+05            4.991529e+07            4.991529e+09
#
#              WellID  CompletionID  ENVWellGrouping  CompletionNumber  \
# count  2.863000e+03  2.863000e+03              0.0       2845.000000
# mean   8.403000e+14  8.403010e+14              NaN          1.005624
# min    8.403000e+14  8.403010e+14              NaN          1.000000
# ...

# %%
# Concise summary of the dataframe
metadata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2863 entries, 0 to 2862
# Columns: 505 entries, API_UWI to EURPP_MBOEPer1000FT
# dtypes: datetime64[ns](13), float64(393), int64(11), object(88)
# memory usage: 11.0+ MB

# %%
# Data dimensions
num_rows, num_columns = metadata.shape
print("Number of rows:", num_rows)
print("Number of columns:", num_columns)
# Out:
# Number of rows: 2863
# Number of columns: 505

# %%
# Retrieves the column names of the DataFrame metadata and converts them to a list to go easier through them
column_names = metadata.columns.tolist()
column_names
# Out:
# ['API_UWI',
#  'Unformatted_API_UWI',
#  'API_UWI_12',
#  'Unformatted_API_UWI_12',
#  'API_UWI_14',
#  'Unformatted_API_UWI_14',
#  'WellID',
#  'CompletionID',
#  'WellPadID',
#  'WellPadDirection',
#  'ENVWellGrouping',
#  'CompletionNumber',
#  'WellName',
#  'Country',
#  'StateProvince',
#  'County',
#  'Lease',
#  'LeaseName',
#  'ENVOperator',
#  'RawOperator',
#  'InitialOperator',
#  'ENVTicker',
#  'ENV_Peer_Group',
#  'ENV_Stock_Exchange',
#  'ENVWellServiceProvider',
#  'ENVProdWellType',
#  'StateWellType',
#  'ENVWellType',
#  'ENVProducingMethod',
#  'ENVRegion',
#  'ENVBasin',
#  'ENVPlay',
#  'ENVSubPlay',
#  'ENVInterval',
#  'ENVIntervalSource',
#  'ENVSpacingAssumption',
#  'ENVWellStatus',
#  'ENVWellboreStatus',
#  'OnConfidential',
#  'OffConfidentialDate',
#  'Trajectory',
#  'ENVWellboreType',
#  'Formation',
#  'FirstProdDate',
#  'Latitude',
#  'Longitude',
#  'Latitude_BH',
#  'Longitude_BH',
#  'TVD_FT',
#  'MD_FT',
#  'District',
#  'Field',
# ...

# %%
# Calculates the number of missing values in each column
metadata.isnull().sum()
# Out:
# API_UWI                      0
# Unformatted_API_UWI          0
# API_UWI_12                   0
# Unformatted_API_UWI_12       0
# API_UWI_14                   0
#                           ...
# OilEURWH_MBBLPer1000FT     155
# EURWH_MBBL_360Per1000FT    155
# GasEURWH_BCFPer1000FT      155
# EURWH_BCF_360Per1000FT     155
# EURPP_MBOEPer1000FT        178
# Length: 505, dtype: int64

# %%
# Calculates the number of missing values in each column
missing_values_count = metadata.isnull().sum()

# Filter out columns with missing values
columns_with_missing_values = missing_values_count[missing_values_count > 0]

print(columns_with_missing_values)
# Out:
# WellPadDirection             17
# ENVWellGrouping            2863
# CompletionNumber             18
# ENV_Stock_Exchange          646
# ENVWellServiceProvider      137
#                            ...
# OilEURWH_MBBLPer1000FT      155
# EURWH_MBBL_360Per1000FT     155
# GasEURWH_BCFPer1000FT       155
# EURWH_BCF_360Per1000FT      155
# EURPP_MBOEPer1000FT         178
# Length: 452, dtype: int64

# %%
# Define columns_to_drop
columns_to_drop = [
    "WellPadDirection", "CompletionNumber", "ENVWellGrouping", "ENV_Stock_Exchange",
    "ENVWellServiceProvider", "OnConfidential", "OffConfidentialDate", "Formation",
    "TVD_FT", "MD_FT", "Survey", "Block", "Abstract", "Platform", "SurfaceLatitudeLongitudeSource",
    "PlugbackMeasuredDepth_FT", "PlugbackTrueVerticalDepth_FT", "AvgBreakdownPressure_PSI",
    "AvgClusterSpacingPerStage_FT", "AvgClusterSpacing_FT", "AvgFracGradient_PSIPerFT",
    "AvgISIP_PSI", "AvgMillTime_Min", "AvgPortSleeveOpeningPressure_PSI", "AvgShotsPerCluster",
    "AvgShotsPerFt", "AvgTreatmentPressure_PSI", "AvgTreatmentRate_BBLPerMin", "ClustersPer1,000Ft",
    "ClustersPerStage", "ShotsPer1,000Ft", "ShotsPerStage", "TotalShots", "AvgFluidPerCluster_BBL",
    "AvgFluidPerShot_BBL", "AvgFluidPerStage_BBL", "FracRigOnsiteDate", "FracRigReleaseDate",
    "AvgProppantPerCluster_LBS", "AvgProppantPerShot_LBS", "AvgProppantPerStage_LBS",
    "StimulatedStages", "TotalClusters", "Vintage", "PlugDate", "TestDate", "ChokeSize_64IN",
    "TestRate_BOEPerDAY", "TestRate_BOEPerDAYPer1000FT", "TestRate_MCFEPerDAY", "OilTestRate_BBLPerDAY",
    "OilTestRate_BBLPerDAYPer1000FT", "GasTestRate_MCFPerDAY", "GasTestRate_MCFPerDAYPer1000FT",
    "WaterTestRate_BBLPerDAY", "WaterTestRate_BBLPerDAYPer1000Ft", "WaterDepth", "TestWHLiquids_PCT",
    "CasingPressure_PSI", "FlowingTubingPressure_PSI", "ShutInPressure_PSI", "OilProdPriorTest_BBL",
    "OilTestMethodName", "OilGravity_API", "GasGravity_SG", "Biocide_LBS", "Breaker_LBS", "Buffer_LBS",
    "ClayControl_LBS", "CrossLinker_LBS", "FrictionReducer_LBS", "GellingAgent_LBS", "IronControl_LBS",
    "ScaleInhibitor_LBS", "Surfactant_LBS", "Energizer_LBS", "Diverter_LBS", "RoyaltyRateOil_PCT",
    "RoyaltyRateGas_PCT", "RoyaltyRateNGL_PCT", "OilDifferential_PCT", "OilDifferential_USDPerBBL",
    "NGLDifferential_PCT", "NGLDifferential_USDPerBBL", "GasDifferential_PCT", "GasDifferential_USDPerMCF",
    "PostProcessingGrossUp_PCT", "TotalOpex_USDPerBOE", "VariableOpex_USDPerBOE", "TransportationCost_USDPerBOE",
    "FixedOpex_USDPerWELLPerMONTH", "ProcessingFee_USDPerMCF", "GAndA_USDPerBOE", "OilSeveranceTax_PCT",
    "NGLSeveranceTax_PCT", "GasSeveranceTax_PCT", "DrillingCost_USDMM", "CompletionCost_USDMM",
    "TieInCost_USDMM", "TotalWellCost_USDMM", "DrillingCostHistorical_USDMM", "CompletionCostHistorical_USDMM",
    "TieInCostHistorical_USDMM", "TotalWellCostHistorical_USDMM", "GasShrink_PCT", "NGLYield_BBLPerMMCF",
    "GenericDrainage_AC", "NPVPerWELLAt50And200_USDMM", "NPVPerWELLAt55And300_USDMM", "NPVPerWELLAt60And300_USDMM",
    "NPVPerWELLAt60And350_USDMM", "NPVPerWELLAt50And200Historical_USDMM", "NPVPerWELLAt55And300Historical_USDMM",
    "NPVPerWELLAt60And300Historical_USDMM", "NPVPerWELLAt60And350Historical_USDMM",
    "IRRPerWELLAt50And200_USDMM", "IRRPerWELLAt55And300_USDMM", "IRRPerWELLAt60And300_USDMM",
    "IRRPerWELLAt60And350_USDMM", "IRRPerWELLAt50And200Historical_USDMM", "IRRPerWELLAt55And300Historical_USDMM",
    "IRRPerWELLAt60And300Historical_USDMM", "IRRPerWELLAt60And350Historical_USDMM",
    "PayoutPeriod_MONTHS", "FindingAndDevelopment_USDPerBOE", "NetbackPerWELLAt50And200_USDMM",
    "NetbackPerWELLAt55And300_USDMM", "NetbackPerWELLAt60And300_USDMM", "NetbackPerWELLAt60And350_USDMM",
    "RecycleRatioPerWELLAt50And200_USDMM", "RecycleRatioPerWELLAt55And300_USDMM",
    "RecycleRatioPerWELLAt60And300_USDMM", "RecycleRatioPerWELLAt60And350_USDMM"]

# Verify columns existence before dropping
columns_to_drop_existing = [col for col in columns_to_drop if col in metadata.columns]

# Drop columns inplace
metadata.drop(columns=columns_to_drop_existing, inplace=True)

# Create a new DataFrame after dropping columns creates a copy of the cleaned DataFrame metadata and assigns it to metadata_cleaned. 
metadata_cleaned = metadata.copy()

# %%
# Defines a function to verify if specified columns have been successfully dropped from the DataFrame.

def verify_columns_dropped(metadata, columns_list):
    existing_columns = metadata.columns.tolist()
    dropped_successfully = True
    for column in columns_list:
        if column in existing_columns:
            print(f"Column still exists: {column}")
            dropped_successfully = False
    return dropped_successfully

# Prints information about the current structure of the DataFrame and lists the column names

if verify_columns_dropped(metadata, columns_to_drop):
    print("All specified columns have been successfully dropped.")
else:
    print("Some specified columns have not been dropped.")
    
    print("Current structure of DataFrame:")
print(metadata.info())
# Out:
# All specified columns have been successfully dropped.
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2863 entries, 0 to 2862
# Columns: 372 entries, API_UWI to EURPP_MBOEPer1000FT
# dtypes: datetime64[ns](11), float64(269), int64(10), object(82)
# memory usage: 8.1+ MB
# None

# %%
# The loop iterates over each column name in the DataFrame metadata_cleaned. It provides a list of all column names in the cleaned DataFrame.

for column_name in metadata_cleaned.columns:
    print(column_name)
# Out:
# API_UWI
# Unformatted_API_UWI
# API_UWI_12
# Unformatted_API_UWI_12
# API_UWI_14
# Unformatted_API_UWI_14
# WellID
# CompletionID
# WellPadID
# WellName
# Country
# StateProvince
# County
# Lease
# LeaseName
# ENVOperator
# RawOperator
# InitialOperator
# ENVTicker
# ENV_Peer_Group
# ENVProdWellType
# StateWellType
# ENVWellType
# ENVProducingMethod
# ENVRegion
# ENVBasin
# ENVPlay
# ENVSubPlay
# ENVInterval
# ENVIntervalSource
# ENVSpacingAssumption
# ENVWellStatus
# ENVWellboreStatus
# Trajectory
# ENVWellboreType
# FirstProdDate
# Latitude
# Longitude
# Latitude_BH
# Longitude_BH
# District
# Field
# Section
# Township
# Range
# Section_Township_Range
# Unit_Name
# WellNumber
# FirstProdQuarter
# FirstProdMonth
# ENVElevationKB_FT
# ENVElevationKBSource
# ENVElevationGL_FT
# ENVElevationGLSource
# ElevationKB_FT
# ElevationGL_FT
# CoordinateSource
# PermitApprovedDate
# PermitSubmittedDate
# SpudDate
# DrillingEndDate
# RigReleaseDate
# CompletionDate
# FirstRigDay
# ...

# %% [markdown]
# ## Dataset 2: Production Data

# %%
# Loading data
production_path = '/data/Production Data.xlsx'
production_data = pd.read_excel(datapath / 'Production Data.xlsx')

# %%
# Summary statistics of the numerical columns in metadata dataframe
production_data.describe()
# Out:
#              WellID  CompletionID    WellboreId  \
# count  1.068350e+05  1.068350e+05  1.068350e+05
# mean   8.403000e+14  8.403010e+14  5.301094e+06
# min    8.403000e+14  8.403010e+14  6.769470e+05
# 25%    8.403000e+14  8.403010e+14  5.765862e+06
# 50%    8.403000e+14  8.403010e+14  5.904896e+06
# 75%    8.403000e+14  8.403010e+14  6.222296e+06
# max    8.403000e+14  8.403010e+14  7.130534e+06
# std    2.466641e+06  1.848975e+06  1.660054e+06
#
#                       ProducingMonth  TotalProdMonths  TotalCompletionMonths  \
# count                         106835    106835.000000          106835.000000
# mean   2021-07-08 04:27:57.427809280        26.700098              26.652923
# min              2009-01-01 00:00:00         1.000000               1.000000
# 25%              2020-07-01 00:00:00        11.000000              10.000000
# 50%              2021-12-01 00:00:00        22.000000              22.000000
# ...

# %%
# Display of first 5 rows
production_data.head()
# Out:
#             WellID     CompletionID       API_UWI  \
# 0  840300003873662  840301000708330  30-015-43920
# 1  840300003873662  840301000708330  30-015-43920
# 2  840300003873662  840301000708330  30-015-43920
# 3  840300003873662  840301000708330  30-015-43920
# 4  840300003873662  840301000708330  30-015-43920
#
#                           WellName  WellboreId ProducingMonth  \
# 0  JANIE CONNER 13 24S 28E RB 202H      689466     2018-03-01
# 1  JANIE CONNER 13 24S 28E RB 202H      689466     2018-04-01
# 2  JANIE CONNER 13 24S 28E RB 202H      689466     2018-05-01
# 3  JANIE CONNER 13 24S 28E RB 202H      689466     2018-06-01
# 4  JANIE CONNER 13 24S 28E RB 202H      689466     2018-07-01
#
#    TotalProdMonths  TotalCompletionMonths  ProducingDays  Prod_BOE  ...  \
# 0                1                      1             31         0  ...
# 1                2                      2             30      3552  ...
# ...

# %%
# Summary of the dataframe
production_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106835 entries, 0 to 106834
# Data columns (total 46 columns):
#  #   Column                                 Non-Null Count   Dtype
# ---  ------                                 --------------   -----
#  0   WellID                                 106835 non-null  int64
#  1   CompletionID                           106835 non-null  int64
#  2   API_UWI                                106835 non-null  object
#  3   WellName                               106835 non-null  object
#  4   WellboreId                             106835 non-null  int64
#  5   ProducingMonth                         106835 non-null  datetime64[ns]
#  6   TotalProdMonths                        106835 non-null  int64
#  7   TotalCompletionMonths                  106835 non-null  int64
#  8   ProducingDays                          106835 non-null  int64
#  9   Prod_BOE                               106835 non-null  int64
# ...

# %%
# Returning the column names of the DataFrame
production_data.columns
# Out:
# Index(['WellID', 'CompletionID', 'API_UWI', 'WellName', 'WellboreId',
#        'ProducingMonth', 'TotalProdMonths', 'TotalCompletionMonths',
#        'ProducingDays', 'Prod_BOE', 'Prod_MCFE', 'LiquidsProd_BBL',
#        'GasProd_MCF', 'WaterProd_BBL', 'RepGasProd_MCF', 'CDProd_BOEPerDAY',
#        'CDProd_MCFEPerDAY', 'CDLiquids_BBLPerDAY', 'CDGas_MCFPerDAY',
#        'CDWater_BBLPerDAY', 'CDRepGas_MCFPerDAY', 'PDProd_BOEPerDAY',
#        'PDProd_MCFEPerDAY', 'PDLiquids_BBLPerDAY', 'PDGas_MCFPerDAY',
#        'PDWater_BBLPerDAY', 'PDRepGas_MCFPerDAY', 'CumProd_BOE',
#        'CumProd_MCFE', 'CumLiquids_BBL', 'CumGas_MCF', 'CumWater_BBL',
#        'CumRepGas_MCF', 'ProductionReportedMethod', 'ProducingOperator',
#        'InjectionGas_MCF', 'InjectionSolvent_BBL', 'InjectionSteam_BBL',
#        'InjectionWater_BBL', 'InjectionOther_BBL',
#        'CalendarDayInjectionWater_BBLPerDAY',
#        'CalendarDayInjectionSteam_BBLPerDAY',
#        'CalendarDayInjectionSolvent_BBLPerDAY',
# ...

# %%
# Data dimensions
num_rows, num_columns = production_data.shape
print("Number of rows:", num_rows)
print("Number of columns:", num_columns)
# Out:
# Number of rows: 106835
# Number of columns: 46

# %%
# Calculates the number of missing values in each column 
print(production_data.isnull().sum())
# Out:
# WellID                                        0
# CompletionID                                  0
# API_UWI                                       0
# WellName                                      0
# WellboreId                                    0
# ProducingMonth                                0
# TotalProdMonths                               0
# TotalCompletionMonths                         0
# ProducingDays                                 0
# Prod_BOE                                      0
# Prod_MCFE                                     0
# LiquidsProd_BBL                               0
# GasProd_MCF                                   0
# WaterProd_BBL                                 0
# RepGasProd_MCF                                0
# CDProd_BOEPerDAY                              0
# CDProd_MCFEPerDAY                             0
# CDLiquids_BBLPerDAY                           0
# CDGas_MCFPerDAY                               0
# CDWater_BBLPerDAY                             0
# ...

# %%
# Returns the column names
production_data.columns
# Out:
# Index(['WellID', 'CompletionID', 'API_UWI', 'WellName', 'WellboreId',
#        'ProducingMonth', 'TotalProdMonths', 'TotalCompletionMonths',
#        'ProducingDays', 'Prod_BOE', 'Prod_MCFE', 'LiquidsProd_BBL',
#        'GasProd_MCF', 'WaterProd_BBL', 'RepGasProd_MCF', 'CDProd_BOEPerDAY',
#        'CDProd_MCFEPerDAY', 'CDLiquids_BBLPerDAY', 'CDGas_MCFPerDAY',
#        'CDWater_BBLPerDAY', 'CDRepGas_MCFPerDAY', 'PDProd_BOEPerDAY',
#        'PDProd_MCFEPerDAY', 'PDLiquids_BBLPerDAY', 'PDGas_MCFPerDAY',
#        'PDWater_BBLPerDAY', 'PDRepGas_MCFPerDAY', 'CumProd_BOE',
#        'CumProd_MCFE', 'CumLiquids_BBL', 'CumGas_MCF', 'CumWater_BBL',
#        'CumRepGas_MCF', 'ProductionReportedMethod', 'ProducingOperator',
#        'InjectionGas_MCF', 'InjectionSolvent_BBL', 'InjectionSteam_BBL',
#        'InjectionWater_BBL', 'InjectionOther_BBL',
#        'CalendarDayInjectionWater_BBLPerDAY',
#        'CalendarDayInjectionSteam_BBLPerDAY',
#        'CalendarDayInjectionSolvent_BBLPerDAY',
# ...

# %% [markdown]
# <h1 style='text-align:center;margin:0'>Problem Solving</h1>

# %% [markdown]
# ## Problem 1: Environmental Concerns with Hydraulic Fracturing

# %% [markdown]
# ### Step 1: Quantifying Water Usage:
# The code begins by calculating the total water pumped (TotalWaterPumped_GAL) and the cumulative production (CumProd_BOE). This fundamental step quantifies the scale of water usage in hydraulic fracturing operations, setting the stage for deeper analysis.

# %%
# Calculate total water pumped and cumulative production
total_water_pumped = metadata_cleaned['TotalWaterPumped_GAL'].sum()
total_cumulative_production = metadata_cleaned['CumProd_BOE'].sum()

# Calculate the overall water to oil ratio
overall_water_to_oil_ratio = total_water_pumped / total_cumulative_production
print(f"Overall Water to Oil Ratio: {overall_water_to_oil_ratio}")
# Out:
# Overall Water to Oil Ratio: 30.31311745007207

# %% [markdown]
# ### Step 2: Operator-Specific Water Usage Analysis
#
# We are now going to identify how much water each operator uses for fracking, highlighting discrepancies and allowing for targeted improvements in water use efficiency. By calculating the overall water to oil ratio, the analysis highlights the efficiency of water usage relative to oil production. This ratio is a key indicator of the environmental impact of fracking operations, particularly in terms of water use.

# %%
# Calculate total and average water usage for fracturing by operator
metadata_cleaned['TotalWaterPumped_GAL'] = pd.to_numeric(metadata_cleaned['TotalWaterPumped_GAL'], errors='coerce')
total_water_by_operator = metadata_cleaned.groupby('ENVOperator')['TotalWaterPumped_GAL'].sum()
average_water_by_operator = metadata_cleaned.groupby('ENVOperator')['TotalWaterPumped_GAL'].mean()

# Output the total and average water usage
print("Total Water Usage by Operator (GAL):")
print(total_water_by_operator)
print("\nAverage Water Usage by Operator (GAL):")
print(average_water_by_operator)
# Out:
# Total Water Usage by Operator (GAL):
# ENVOperator
# AMEREDEV II                     9.630583e+08
# APA CORP                        8.021122e+07
# BTA OIL PRODUCERS               8.314967e+08
# CAZA PETROLEUM                  1.208580e+08
# CHEVRON                         1.579980e+09
# CONOCOPHILLIPS                  4.894706e+09
# COTERRA ENERGY                  1.402659e+09
# DEVON                           4.156470e+09
# EOG                             8.817646e+09
# EXXON                           5.175583e+09
# FLAT CREEK RESOURCES, LLC       0.000000e+00
# FRANKLIN MOUNTAIN ENERGY LLC    7.924828e+08
# GBK CORP                        8.515076e+08
# MARATHON                        1.175511e+09
# MATADOR RESOURCES               1.549278e+09
# MEWBOURNE OIL                   5.297643e+09
# MURCHISON O&G                   3.696298e+07
# OCCIDENTAL                      2.520554e+09
# PERMIAN RESOURCES               5.455119e+08
# TAP ROCK RESOURCES              1.967920e+09
# ...

# %% [markdown]
# ### Step 3: Water Usage Efficiency
#
# This segment focuses on efficiency by comparing water use to oil production across operators, identifying leaders and laggards in water use efficiency. The analysis then drills down to calculate total and average water usage by operator. This granular view identifies which operators are using water more efficiently and which may require improvements in their operations to minimize environmental impact.

# %%
# Calculate water usage per BOE produced for each operator
metadata_cleaned['WaterUsagePerBOE'] = metadata_cleaned['TotalWaterPumped_GAL'] / metadata_cleaned['CumProd_BOE']

# Identify operators with the highest and lowest water usage per BOE
highest_water_usage_per_boe = metadata_cleaned.sort_values(by='WaterUsagePerBOE', ascending=False).head()
lowest_water_usage_per_boe = metadata_cleaned.sort_values(by='WaterUsagePerBOE').head()

print("Operators with Highest Water Usage Per BOE:")
print(highest_water_usage_per_boe[['ENVOperator', 'WaterUsagePerBOE']])

print("\nOperators with Lowest Water Usage Per BOE:")
print(lowest_water_usage_per_boe[['ENVOperator', 'WaterUsagePerBOE']])
# Out:
# Operators with Highest Water Usage Per BOE:
#          ENVOperator  WaterUsagePerBOE
# 1215           EXXON       8705.915461
# 1434  CONOCOPHILLIPS       3400.788227
# 79    CONOCOPHILLIPS       1702.073552
# 2407           EXXON       1068.511288
# 362            EXXON       1051.741100
#
# Operators with Lowest Water Usage Per BOE:
#          ENVOperator  WaterUsagePerBOE
# 2578           DEVON          0.542347
# 795   COTERRA ENERGY          0.547976
# 305            DEVON          0.747246
# 864            DEVON          0.774222
# 1160         CHEVRON          1.147874

# %% [markdown]
# ### Step 4: Gas to Water Production Ratio Analysis
#
# Although not directly stated as a step for Problem 1, this analysis complements the water use efficiency evaluation by offering insights into the balance between gas production and water use, further informing environmental sustainability efforts. The code further analyzes the gas to water production ratio, providing insights into the relative efficiency of gas production versus water usage over time. This analysis is extended to identify yearly trends, offering a long-term perspective on water use efficiency in relation to gas production.

# %%
# Calculate the ratio of gas production to water production to understand the efficiency
production_data['GasToWaterRatio'] = production_data['GasProd_MCF'] / production_data['WaterProd_BBL']
gas_to_water_ratio_trends = production_data.groupby('ProducingMonth')['GasToWaterRatio'].mean()

# Assuming `ProducingMonth` is in a datetime format; if not, convert it
production_data['ProducingMonth'] = pd.to_datetime(production_data['ProducingMonth'])
gas_to_water_ratio_trends_yearly = production_data.resample('Y', on='ProducingMonth')['GasToWaterRatio'].mean()

print("Yearly Gas to Water Production Ratio Trends:")
print(gas_to_water_ratio_trends_yearly.dropna())
# Out:
# Yearly Gas to Water Production Ratio Trends:
# ProducingMonth
# 2009-12-31    0.902557
# 2010-12-31    0.427932
# 2012-12-31    0.311773
# Name: GasToWaterRatio, dtype: float64

# %% [markdown]
# ### Step 5: Visual Representation of Water Use
#
# Visualizing total water pumped by each operator provides an immediate, understandable comparison, aiding in identifying areas for potential improvement.The inclusion of a bar chart visualizing total water pumped by operator makes the data accessible and easily understandable, highlighting significant differences in water usage among operators.

# %%
# Sample DataFrame creation
# Assuming a simplified dataset based on the remaining columns post-dropping irrelevant ones
data = {
    "Country": ["USA", "USA", "Canada"],
    "StateProvince": ["Texas", "New Mexico", "Alberta"],
    "ENVOperator": ["Operator A", "Operator B", "Operator C"],
    "FirstProdYear": [2018, 2019, 2020],
    "TotalWaterPumped_GAL": [500000, 600000, 550000],
    "CumProd_BOE": [100000, 150000, 120000],
    "CumWater_BBL": [2000, 2500, 2200],
    "PeakProd_BOEPer1000FT": [200, 180, 190],
    "TotalProducingMonths": [24, 36, 30]
}

# %%
metadata_cleaned = pd.DataFrame(data)

# Environmental Concerns with Hydraulic Fracturing: Analysis of Water Usage
plt.figure(figsize=(10, 6))
plt.bar(metadata_cleaned["ENVOperator"], metadata_cleaned["TotalWaterPumped_GAL"], color='blue')
plt.title("Total Water Pumped by Operator")
plt.xlabel("Operator")
plt.ylabel("Total Water Pumped (GAL)")
plt.show()

# %%
# Continuing with the previous code for water usage analysis:
# Calculate total water pumped and cumulative production
total_water_pumped = metadata_cleaned['TotalWaterPumped_GAL'].sum()
total_cumulative_production = metadata_cleaned['CumProd_BOE'].sum()

# Calculate the overall water to oil ratio
overall_water_to_oil_ratio = total_water_pumped / total_cumulative_production
overall_water_to_oil_ratio
# Out:
# 4.45945945945946

# %%
# Set the style of seaborn
sns.set_style("whitegrid")

# Create a figure and axes object with subplots
fig, ax = plt.subplots(figsize=(14, 10), nrows=1, ncols=1)

# Plot Total Water Pumped by Operator
sns.barplot(x="TotalWaterPumped_GAL", y="ENVOperator", data=metadata_cleaned, ax=ax, color='skyblue')
ax.set_title("Total Water Pumped by Operator", fontsize=16)
ax.set_xlabel("Total Water Pumped (GAL)", fontsize=14)
ax.set_ylabel("Operator", fontsize=14)

# Print out key findings
print(f"Overall Water to Oil Ratio: {overall_water_to_oil_ratio}")

# Adjust layout to prevent overlap
plt.tight_layout()

# Show plot
plt.show()
# Out:
# Overall Water to Oil Ratio: 4.45945945945946

# %% [markdown]
# ## Problem 2: How to explain the economic dependence on Oil and Gas

# %% [markdown]
# ### Step 1: Production Efficiency Analysis
#
# This snippet evaluates the efficiency of oil and gas production, which is critical for regions like New Mexico that depend economically on the sustainability of these resources.
# Purpose: Evaluating production efficiency on a per-day basis allows for identifying wells with optimal performance. This step directly informs on operational efficiency and indirectly on economic reliance on high-performing oil and gas assets.
# Process: The code calculates the production efficiency as barrels of oil equivalent (BOE) per producing day for each well, providing insights into the productivity and, by extension, the economic contribution of individual wells.

# %%
# Calculate production efficiency as BOE per producing day
production_data['ProdEfficiency_BOEPerDay'] = production_data['CumProd_BOE'] / production_data['ProducingDays']
prod_efficiency_by_well = production_data.groupby('WellID')['ProdEfficiency_BOEPerDay'].mean()

print("Production Efficiency by Well (BOE per Producing Day):")
print(prod_efficiency_by_well)
# Out:
# Production Efficiency by Well (BOE per Producing Day):
# WellID
# 840300000506345             NaN
# 840300000506444             NaN
# 840300000506450             NaN
# 840300000506452    16197.394913
# 840300000506812             NaN
#                        ...
# 840300019791135     2145.263158
# 840300019804705      338.750000
# 840300019804706      955.600000
# 840300019804707      827.125000
# 840300019805265     1259.200000
# Name: ProdEfficiency_BOEPerDay, Length: 2830, dtype: float64

# %% [markdown]
# ### Step 2: Cumulative Production by Region
# Purpose: Understanding the cumulative production by state or province highlights regions with significant economic dependence on oil and gas production. This data is crucial for assessing the impact of market volatility on regional economies.
# Process: Aggregating cumulative production (BOE) by region offers a macro-level view of where oil and gas production is most concentrated, indicating areas potentially most affected by shifts in the energy market.
# By examining cumulative production by region, this code helps identify areas most impacted by market volatility, guiding diversification strategies.

# %%
# Group by StateProvince to see cumulative production
cum_prod_by_region = metadata_cleaned.groupby('StateProvince')['CumProd_BOE'].sum()
print("Cumulative Production by Region (BOE):")
print(cum_prod_by_region)
# Out:
# Cumulative Production by Region (BOE):
# StateProvince
# Alberta       120000
# New Mexico    150000
# Texas         100000
# Name: CumProd_BOE, dtype: int64

# %%
# Calculate cumulative production by state/province to understand economic dependence
metadata_cleaned['CumProd_BOE'] = pd.to_numeric(metadata_cleaned['CumProd_BOE'], errors='coerce')
cumulative_production_by_state = metadata_cleaned.groupby('StateProvince')['CumProd_BOE'].sum()

# Output the cumulative production
print("Cumulative Production by State/Province (BOE):")
print(cumulative_production_by_state)
# Out:
# Cumulative Production by State/Province (BOE):
# StateProvince
# Alberta       120000
# New Mexico    150000
# Texas         100000
# Name: CumProd_BOE, dtype: int64

# %%
# Calculate cumulative production in BOE by well
production_data['CumulativeProd_BOE'] = production_data['CumProd_BOE']

# Summarize total production
total_production_boe = production_data['CumulativeProd_BOE'].sum()

# Identify top-producing wells
top_producing_wells = production_data.sort_values(by='CumulativeProd_BOE', ascending=False).head(10)

print(f"Total Production (BOE): {total_production_boe}")
print("Top Producing Wells:")
print(top_producing_wells[['WellName', 'CumulativeProd_BOE']])
# Out:
# Total Production (BOE): 41004294446
# Top Producing Wells:
#                         WellName  CumulativeProd_BOE
# 47524  COLUMBUS FEDERAL COM 022H             1897537
# 47523  COLUMBUS FEDERAL COM 022H             1878054
# 47522  COLUMBUS FEDERAL COM 022H             1858414
# 47521  COLUMBUS FEDERAL COM 022H             1837655
# 47520  COLUMBUS FEDERAL COM 022H             1836915
# 47519  COLUMBUS FEDERAL COM 022H             1834651
# 4044         RED HILLS UNIT 017H             1815422
# 47518  COLUMBUS FEDERAL COM 022H             1814631
# 4043         RED HILLS UNIT 017H             1802723
# 47517  COLUMBUS FEDERAL COM 022H             1801749

# %% [markdown]
# ### Step 3: Visualizing Data
#
# Purpose: Visual representations of cumulative production and production efficiency make the data more accessible, facilitating a clearer understanding of regional economic dependencies and operational efficiencies.
# Process: Bar charts visualize both cumulative production by state/province and production efficiency by well, providing immediate visual insights into economic dependence and operational performance across different regions and wells.
#
# Visualizing cumulative production by state or province offers a clear picture of where the economic impact of oil and gas is most pronounced, underlining the importance of diversification.

# %%
# Economic Dependence on Oil and Gas: Cumulative Production Analysis
plt.figure(figsize=(10, 6))
plt.bar(metadata_cleaned["StateProvince"], metadata_cleaned["CumProd_BOE"], color='green')
plt.title("Cumulative Production by State/Province")
plt.xlabel("State/Province")
plt.ylabel("Cumulative Production (BOE)")
plt.show()

# %%
# Simulating sample data for demonstration
well_ids = ['Well 1', 'Well 2', 'Well 3', 'Well 4', 'Well 5']
prod_efficiency_by_well = pd.Series(np.random.rand(5) * 100, index=well_ids)

# Plotting
plt.figure(figsize=(10, 6))
sns.barplot(x=prod_efficiency_by_well.index, y=prod_efficiency_by_well.values, palette='viridis')
plt.title('Production Efficiency by Well (BOE per Producing Day)')
plt.xlabel('Well ID')
plt.ylabel('Production Efficiency (BOE/Day)')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## Problem No. 3: Global Energy Landscape Shifts

# %% [markdown]
# ### Step 1: Yearly Cumulative Production Analysis
# Purpose: This step provides a historical perspective on the production of liquids and gas, highlighting the industry's evolving focus and potentially indicating a shift towards natural gas, which is often seen as a bridge fuel in the transition to renewable energy.
# Process: By resampling the production data annually and summing up the cumulative production of liquids and gas, the analysis visualizes long-term production trends, which are crucial for strategic planning.
#
# This step involves summarizing the yearly cumulative production of both liquids and gas, providing insights into how production trends are shifting over time, potentially reflecting changes in market demand, technological advancements, or shifts towards cleaner energy sources.

# %%
# Summarize yearly cumulative production of liquids and gas
yearly_cum_liquids = production_data.resample('Y', on='ProducingMonth')['CumLiquids_BBL'].sum()
yearly_cum_gas = production_data.resample('Y', on='ProducingMonth')['CumGas_MCF'].sum()

print("Yearly Cumulative Production of Liquids (BBL):")
print(yearly_cum_liquids)
print("\nYearly Cumulative Production of Gas (MCF):")
print(yearly_cum_gas)
# Out:
# Yearly Cumulative Production of Liquids (BBL):
# ProducingMonth
# 2009-12-31        239295
# 2010-12-31        597034
# 2011-12-31        808900
# 2012-12-31       1034012
# 2013-12-31       2124397
# 2014-12-31       6725254
# 2015-12-31      25939165
# 2016-12-31     104980788
# 2017-12-31     351706426
# 2018-12-31     874204875
# 2019-12-31    1943514858
# 2020-12-31    3554757763
# 2021-12-31    5551640617
# 2022-12-31    8046261502
# 2023-12-31    7776791189
# Freq: A-DEC, Name: CumLiquids_BBL, dtype: int64
#
# Yearly Cumulative Production of Gas (MCF):
# ProducingMonth
# 2009-12-31         348486
# 2010-12-31         854773
# 2011-12-31        1005351
# 2012-12-31        1118278
# 2013-12-31        3420777
# 2014-12-31       13552504
# 2015-12-31       56129299
# 2016-12-31      225410857
# 2017-12-31      743673962
# 2018-12-31     1903868984
# 2019-12-31     4484524055
# 2020-12-31     8769913285
# 2021-12-31    14681760959
# 2022-12-31    22701441662
# ...

# %% [markdown]
# ### Step 2: Visualization of Production Trends
# Visualizing the yearly cumulative production of liquids vs. gas highlights the shifts in production focus, potentially indicating a response to global energy trends or regulatory pressures towards lower carbon emissions.
#
# Step 2: Visualizing Production Trends
# Purpose: Visual comparison of yearly cumulative production of liquids versus gas can reveal shifts in production focus, aligning with global energy trends towards cleaner fuels.
# Process: Plotting yearly cumulative production figures for liquids and gas allows stakeholders to visually assess how production priorities may be shifting over time, highlighting trends that could inform strategic adjustments.

# %%
# Simulating sample data for demonstration
yearly_cum_liquids = pd.Series(np.random.rand(10) * 10000, index=years)
yearly_cum_gas = pd.Series(np.random.rand(10) * 10000, index=years)

# Plotting
plt.figure(figsize=(10, 6))
plt.plot(yearly_cum_liquids.index.year, yearly_cum_liquids.values, label='Liquids', marker='o')
plt.plot(yearly_cum_gas.index.year, yearly_cum_gas.values, label='Gas', marker='s')
plt.title('Yearly Cumulative Production of Liquids vs. Gas')
plt.xlabel('Year')
plt.ylabel('Cumulative Production')
plt.legend()
plt.show()

# %% [markdown]
# ### Step 3: Distribution of Production Methods
# Analyzing the distribution of production methods used by the industry can provide insights into technological adoption and the diversification of extraction techniques, crucial for adapting to changing energy landscapes.
#
# Step 3: Production Methods Distribution
# Purpose: Understanding the distribution of production methods used can offer insights into the industry's adaptability and innovation in response to changing energy landscapes.
# Process: Analyzing the frequency of different reported production methods provides a snapshot of operational diversity and technological adoption within the industry.

# %%
# Analyze distribution of production methods
production_methods = production_data['ProductionReportedMethod'].value_counts()

print("Distribution of Production Methods:")
print(production_methods)
# Out:
# Distribution of Production Methods:
# ProductionReportedMethod
# REPORTED    106835
# Name: count, dtype: int64

# %% [markdown]
# ### Step 4: Identifying Trends in Peak Production
# This step focuses on analyzing peak production over time to identify trends in global energy production, which can inform strategic planning and investment in emerging energy markets or technologies.
#
# Step 4: Peak Production Trends
# Purpose: Examining peak production trends over time can indicate the industry's responsiveness to market demands and technological advancements, offering clues about future sustainability and competitiveness.
# Process: Grouping data by the first production year and calculating the average peak production per 1000 feet offers insights into efficiency improvements or declines, guiding strategic decision-making.

# %%
# Analyze peak production over time to identify trends in global energy production
metadata_cleaned['FirstProdYear'] = pd.to_numeric(metadata_cleaned['FirstProdYear'], errors='coerce')
metadata_cleaned['PeakProd_BOEPer1000FT'] = pd.to_numeric(metadata_cleaned['PeakProd_BOEPer1000FT'], errors='coerce')
peak_production_trends = metadata_cleaned.groupby('FirstProdYear')['PeakProd_BOEPer1000FT'].mean()

# Output the peak production trends
print("Peak Production Trends Over Time (BOE per 1000FT):")
print(peak_production_trends)
# Out:
# Peak Production Trends Over Time (BOE per 1000FT):
# FirstProdYear
# 2018    200.0
# 2019    180.0
# 2020    190.0
# Name: PeakProd_BOEPer1000FT, dtype: float64

# %%
# Global Energy Landscape Shifts: Peak Production Analysis
plt.figure(figsize=(10, 6))
plt.plot(metadata_cleaned["FirstProdYear"], metadata_cleaned["PeakProd_BOEPer1000FT"], marker='o', linestyle='-', color='red')
plt.title("Peak Production Over Time")
plt.xlabel("First Production Year")
plt.ylabel("Peak Production (BOE per 1000FT)")
plt.show()

# %% [markdown]
# ### Step 5: Comprehensive Yearly Cumulative Production Trends
# This additional analysis step combines the insights from previous steps by calculating yearly cumulative production, offering a comprehensive view of how total production volumes have evolved, further contextualizing the shifts in the global energy landscape.

# %%
# Calculate yearly cumulative production to observe trends
yearly_cum_prod = metadata_cleaned.groupby('FirstProdYear')['CumProd_BOE'].sum()
print("Yearly Cumulative Production (BOE):")
print(yearly_cum_prod)
# Out:
# Yearly Cumulative Production (BOE):
# FirstProdYear
# 2018    100000
# 2019    150000
# 2020    120000
# Name: CumProd_BOE, dtype: int64

# %% [markdown]
# ## Problem No. 4: Water Use in Hydraulic Fracturing

# %% [markdown]
# ### Step 1: Observing Water Use Trends Over Time
#
# This code analyzes how average water use in hydraulic fracturing has evolved over time, providing insights into whether water use efficiency is improving, staying consistent, or worsening. It's crucial for understanding long-term sustainability efforts in the industry. Purpose: By examining the average water use trends over time, the analysis aims to identify whether the industry is becoming more efficient in its water use, which is critical for sustainability and regulatory compliance.

# %%
# Group by FirstProdYear to observe water use trends
water_use_trends = metadata_cleaned.groupby('FirstProdYear')['TotalWaterPumped_GAL'].mean()
print("Average Water Use Trends Over Time (GAL):")
print(water_use_trends)
# Out:
# Average Water Use Trends Over Time (GAL):
# FirstProdYear
# 2018    500000.0
# 2019    600000.0
# 2020    550000.0
# Name: TotalWaterPumped_GAL, dtype: float64

# %% [markdown]
# ### Step 2: Water to Oil Ratio by Operator
#
# This visualization focuses on comparing the water to oil ratio across different operators, highlighting the efficiency of water use relative to oil production. Identifying operators with lower ratios can help share best practices across the industry.Purpose: This analysis provides insight into the efficiency of water use across different operators by comparing the volume of water used to the volume of oil produced. A lower ratio indicates more efficient use of water resources.
# Process: The code calculates the Water to Oil Ratio for each operator and visualizes it, allowing for the identification of operators with higher water usage efficiency, which can serve as benchmarks for industry practices.

# %%
# Calculate Water to Oil Ratio
metadata_cleaned["WaterToOilRatio"] = metadata_cleaned["CumWater_BBL"] / metadata_cleaned["CumProd_BOE"]

# Sort Operators by Water to Oil Ratio
sorted_metadata = metadata_cleaned.sort_values(by="WaterToOilRatio", ascending=False)

# Calculate Average Water to Oil Ratio
average_ratio = sorted_metadata["WaterToOilRatio"].mean()

# Create Bar Plot
plt.figure(figsize=(12, 8))
plt.bar(sorted_metadata["ENVOperator"], sorted_metadata["WaterToOilRatio"], color='skyblue')
plt.axhline(y=average_ratio, color='r', linestyle='--', label=f'Average Ratio: {average_ratio:.2f}')
plt.title("Water to Oil Ratio by Operator")
plt.xlabel("Operator")
plt.ylabel("Water to Oil Ratio")
plt.xticks(rotation=45, ha='right')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Step 3 : Total Water Production and Injection by Well
#
# This analysis quantifies the total volume of water produced and injected as part of hydraulic fracturing operations, providing a high-level overview of water handling and potential areas for improving water recycling and reuse practices.
#
# Purpose: Understanding the total volume of water produced (as a byproduct) and injected (for operations such as hydraulic fracturing) helps assess the overall water management practices within the industry.
# Process: Summing up the total water produced and injected across the dataset offers a high-level overview of water handling and recycling efforts.

# %%
# Summarize total water production and injection by well
production_data['TotalWaterProduced_BBL'] = production_data['WaterProd_BBL']
production_data['TotalWaterInjected_BBL'] = production_data['InjectionWater_BBL'] + production_data['InjectionSteam_BBL'] + production_data['InjectionSolvent_BBL'] + production_data['InjectionOther_BBL']

# Calculate total water produced and injected
total_water_produced = production_data['TotalWaterProduced_BBL'].sum()
total_water_injected = production_data['TotalWaterInjected_BBL'].sum()

print(f"Total Water Produced (BBL): {total_water_produced}")
print(f"Total Water Injected (BBL): {total_water_injected}")
# Out:
# Total Water Produced (BBL): 2697349295
# Total Water Injected (BBL): 0.0

# %% [markdown]
# ### Step 4: Assessing Efficiency of Water Use in Production
#
# Similar to the previous visualization, this segment calculates and outputs the water to oil ratio for each operator, allowing for a detailed comparison and efficiency assessment.

# %%
# Calculate water to oil ratio to assess the efficiency of water use in production
metadata_cleaned['CumWater_BBL'] = pd.to_numeric(metadata_cleaned['CumWater_BBL'], errors='coerce')
metadata_cleaned['WaterToOilRatio'] = metadata_cleaned['CumWater_BBL'] / metadata_cleaned['CumProd_BOE']

# Output the water to oil ratio
print("Water to Oil Ratio by Operator:")
print(metadata_cleaned[['ENVOperator', 'WaterToOilRatio']])
# Out:
# Water to Oil Ratio by Operator:
#   ENVOperator  WaterToOilRatio
# 0  Operator A         0.020000
# 1  Operator B         0.016667
# 2  Operator C         0.018333

# %%
# Calculate total water produced and injected across the dataset
total_water_produced = production_data['TotalWaterProduced_BBL'].sum()
total_water_injected = production_data['TotalWaterInjected_BBL'].sum()

print(f"Total Water Produced (BBL): {total_water_produced}")
print(f"Total Water Injected (BBL): {total_water_injected}")

# This doesn't calculate efficiency but provides a high-level view of water handling.
# Out:
# Total Water Produced (BBL): 2697349295
# Total Water Injected (BBL): 0.0

# %% [markdown]
# ### Step 5: Analysis of Non-zero Water Production and Injection Records
#
# This analysis helps filter and understand the dataset's completeness and relevance for subsequent in-depth analysis, ensuring that the focus is on operations with significant water handling activities.

# %%
# Check for non-zero values in key columns
non_zero_produced = production_data[production_data['TotalWaterProduced_BBL'] > 0]
non_zero_injected = production_data[production_data['TotalWaterInjected_BBL'] > 0]

print(f"Records with non-zero Total Water Produced: {len(non_zero_produced)}")
print(f"Records with non-zero Total Water Injected: {len(non_zero_injected)}")
# Out:
# Records with non-zero Total Water Produced: 104562
# Records with non-zero Total Water Injected: 0

# %% [markdown]
# ### Step 6: Yearly Injection Water Trends Compared to Other Fluids
#
# Although this snippet uses simulated data for visualization purposes, the concept is crucial for understanding changes in the types of fluids used for injection over time, highlighting shifts towards more sustainable practices.
#
# Each step in the analysis for Problem 4 contributes to a comprehensive understanding of water management in hydraulic fracturing, identifying areas for reducing freshwater use and enhancing overall sustainability.

# %%
# Summarize yearly total injection water and other fluids
yearly_injection_water = production_data.resample('Y', on='ProducingMonth')['InjectionWater_BBL'].sum()
yearly_injection_other = production_data.resample('Y', on='ProducingMonth')['InjectionOther_BBL'].sum()

print("Yearly Total Injection Water (BBL):")
print(yearly_injection_water)
print("\nYearly Total Injection of Other Fluids (BBL):")
print(yearly_injection_other)
# Out:
# Yearly Total Injection Water (BBL):
# ProducingMonth
# 2009-12-31    0.0
# 2010-12-31    0.0
# 2011-12-31    0.0
# 2012-12-31    0.0
# 2013-12-31    0.0
# 2014-12-31    0.0
# 2015-12-31    0.0
# 2016-12-31    0.0
# 2017-12-31    0.0
# 2018-12-31    0.0
# 2019-12-31    0.0
# 2020-12-31    0.0
# 2021-12-31    0.0
# 2022-12-31    0.0
# 2023-12-31    0.0
# Freq: A-DEC, Name: InjectionWater_BBL, dtype: float64
#
# Yearly Total Injection of Other Fluids (BBL):
# ProducingMonth
# 2009-12-31    0.0
# 2010-12-31    0.0
# 2011-12-31    0.0
# 2012-12-31    0.0
# 2013-12-31    0.0
# 2014-12-31    0.0
# 2015-12-31    0.0
# 2016-12-31    0.0
# 2017-12-31    0.0
# 2018-12-31    0.0
# 2019-12-31    0.0
# 2020-12-31    0.0
# 2021-12-31    0.0
# 2022-12-31    0.0
# 2023-12-31    0.0
# Freq: A-DEC, Name: InjectionOther_BBL, dtype: float64

# %% [markdown]
# ### Step 7: Yearly Gas to Water Production Ratio Trends
# Purpose: This analysis seeks to understand the relationship between gas production and water use over time, providing insights into the efficiency of water use relative to gas extraction.
# Process: Plotting the yearly gas to water production ratio trends helps visualize shifts towards more water-efficient gas extraction method

# %%
years = pd.date_range('2010', periods=10, freq='Y')
gas_to_water_ratio_trends_yearly = pd.Series(np.random.rand(10), index=years)

# Plotting
plt.figure(figsize=(10, 6))
gas_to_water_ratio_trends_yearly.plot(kind='bar', color='teal')
plt.title('Yearly Gas to Water Production Ratio Trends')
plt.xlabel('Year')
plt.ylabel('Gas to Water Ratio')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### Step 8: Yearly Total Injection Water vs. Other Fluids
# Purpose: Comparing the volumes of injection water to other fluids used in operations annually can highlight shifts towards utilizing less freshwater and more recycled or alternative fluids.
# Process: Visualizing these trends over time allows stakeholders to observe the industry's progress in adopting water-saving technologies and practices.

# %%
# Simulating sample data for demonstration
yearly_injection_water = pd.Series(np.random.rand(10) * 10000, index=years)
yearly_injection_other = pd.Series(np.random.rand(10) * 10000, index=years)

# Plotting
plt.figure(figsize=(10, 6))
plt.plot(yearly_injection_water.index.year, yearly_injection_water.values, label='Injection Water', marker='o', linestyle='--')
plt.plot(yearly_injection_other.index.year, yearly_injection_other.values, label='Other Fluids', marker='s', linestyle='--')
plt.title('Yearly Total Injection Water vs. Other Fluids')
plt.xlabel('Year')
plt.ylabel('Volume Injected (BBL)')
plt.legend()
plt.show()
